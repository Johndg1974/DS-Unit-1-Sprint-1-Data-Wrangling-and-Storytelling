# %% [markdown]
# <a href="https://colab.research.google.com/github/Johndg1974/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Copy_of_Copy_of_2_23_2020_%22Joins%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.read_csv('/content/GE_excel.csv', engine='python')
# Out:
#        project id  ... duration
# 0           39409  ...    30.00
# 1          126581  ...    47.18
# 2          138119  ...    28.00
# 3          237090  ...    32.22
# 4          246101  ...    30.00
# ...           ...  ...      ...
# 45952  2147336747  ...    37.83
# 45953  2147346811  ...    59.96
# 45954  2147367534  ...    27.32
# 45955  2147369705  ...    30.00
# 45956  2147460119  ...    40.38
#
# [45957 rows x 17 columns]

# %%
import pandas as pd
df = pd.read_csv('/content/GE_excel.csv', engine='python')
df.describe()
# Out:
#          project id          goal  ...      comments      duration
# count  4.595700e+04  4.595700e+04  ...  45957.000000  45957.000000
# mean   1.080800e+09  1.194271e+04  ...      8.379529     39.995547
# std    6.218057e+08  1.887583e+05  ...    174.015737     17.414458
# min    3.940900e+04  1.000000e-02  ...      0.000000      1.000000
# 25%    5.438962e+08  1.800000e+03  ...      0.000000     30.000000
# 50%    1.078345e+09  4.000000e+03  ...      0.000000     32.000000
# 75%    1.621596e+09  9.862000e+03  ...      3.000000     48.390000
# max    2.147460e+09  2.147484e+07  ...  19311.000000     91.960000
#
# [8 rows x 9 columns]

# %%
df['pledged']
# Out:
# 0        11545.0
# 1           20.0
# 2           56.0
# 3         6535.0
# 4            0.0
#           ...
# 45952      601.0
# 45953       75.0
# 45954    10000.0
# 45955      257.0
# 45956    18758.0
# Name: pledged, Length: 45957, dtype: float64

# %%
df.loc[:,"pledged"].mean()
# Out:
# 4981.076460985962
